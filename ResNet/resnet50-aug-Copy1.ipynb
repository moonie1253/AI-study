# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Activation,Input,BatchNormalization,Flatten, Dense, Conv2D, MaxPool2D,AveragePooling2D,Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 101

# %%
#bottleneck code
class BottleNeck(tf.keras.layers.Layer):
    def __init__(self,num_filters,stride):
        super(BottleNeck,self).__init__()
        self.conv1=Conv2D(filters=num_filters,kernel_size=(1,1),strides=(1,1),padding= 'same')
        self.bn1=BatchNormalization()
        
        self.conv2=Conv2D(filters=num_filters,kernel_size=(3,3), strides=stride,padding='same')
        self.bn2=BatchNormalization()
        
        self.conv3=Conv2D(filters=num_filters*4,kernel_size=(1,1), strides=(1,1),padding='same')
        self.bn3=BatchNormalization()
        #3개의 layer중 1,2번째는 filter 수가 같고, 마지막은 4배의 filter수 갖고 있음
        #stride 변수는 폭에의한 변화 , conv2_x는 1, 나머지는 stride=2로 설정
        
        self.shortcut=Sequential()
        self.shortcut.add(Conv2D(num_filters*4,kernel_size=(1,1), strides=stride,padding='same'))
        self.shortcut.add(BatchNormalization())
        
        #layer 합쳐주는 call
    def call(self, inputs,training=None,**kwargs):
        #none으로 둬서 batch norm drop out이 활성화하게 함 기본적으로 학습 중이지만 필요에 따라 사용자가 지정할 수 있게
        x=self.conv1(inputs)
        x=tf.nn.relu(self.bn1(x)) #batchnormalization실행 후 relu 로 x 업데이트
        x=self.conv2(x)
        x=tf.nn.relu(self.bn2(x))
        x=self.bn3(self.conv3(x))
        output=tf.nn.relu(tf.keras.layers.add([self.shortcut(inputs),x]))
        #output x와 shortcut의 output 더해주어 최종 output 데이터 값
        return output

def _make_layer(num_filters, num_blocks, stride):
    res_block = tf.keras.Sequential()
    res_block.add(BottleNeck(num_filters, stride))

    for _ in range(1, num_blocks):
        res_block.add(BottleNeck(num_filters,stride=1))
    return res_block
"""_ 는 더미 값,
       for _ in range(5):
        print("Hello")
        이 코드의 경우 변수인 0-4까지의 수는 사용하지 않고 print만 되고 있음
        이럴 때 그냥 더미로 _ 를 이용
        """
  #stride 한 번이면 output size 반쪽, 반복적으로 stride가 1이 아니면 점점 줄어들음. 한번만 stride값 변경
  #나머지는 stride 1로 정의

class ResNet(tf.keras.Model):
    def __init__(self,num_block,num_units=10):
        super(ResNet, self).__init__()
        #num block 바꾸면 어떤 resnet 층이든 만들 수 있다.(50 이상)
        
        self.conv1=Conv2D(filters=64,kernel_size=(7,7),strides=(2,2),padding='same')
        self.bn1=BatchNormalization()
        
        self.mp1=MaxPool2D(pool_size=(3,3),strides=(2,2),padding='same')
        self.bn2=BatchNormalization()
        
        self.bt1=_make_layer(64,num_block[0],1)
        self.bt2=_make_layer(128,num_block[1],2)
        self.bt3=_make_layer(256,num_block[2],2)
        self.bt4=_make_layer(512,num_block[3],2)
        
        self.av1=AveragePooling2D(pool_size=(1,1),strides=(1,1))
        self.flatten=Flatten()
        self.ds1=Dense(units=2048,activation='relu')
        self.ds2=Dense(units=1000,activation='relu')
        self.ds3=Dense(units=num_units,activation='softmax')
        
        #input 넣었을 때 call
    def call(self, inputs,training=None,mask=None):
        x=self.conv1(inputs)
        x=self.bn1(x,training=training)
        x=tf.nn.relu(x)
        x=self.mp1(x)
        x=self.bn2(x)
        x=self.bt1(x,training=training)
        x=self.bt2(x,training=training)
        x=self.bt3(x,training=training)
        x=self.bt4(x,training=training)
        x=self.av1(x)
        x=self.flatten(x)
        x=self.ds1(x)
        x=self.ds2(x)
        output=self.ds3(x)
        return output
"""
배치 정규화는 모델을 훈련할 때 주로 사용되며, 각 미니배치의 평균 및 표준편차를 
사용하여 데이터를 정규화합니다. 이때, 훈련 중인지 여부에 따라 정규화에 사용되는 
평균과 표준편차가 달라집니다. training=True로 설정되면 현재 훈련 중이며, 훈련 중에는 
현재 미니배치의 평균과 표준편차를 사용하여 정규화를 수행합니다. training=False로 
설정되면 테스트 또는 추론 중이며, 이때는 훈련 중 계산된 이동 평균 및 이동 표준편차를 
사용하여 정규화를 수행합니다.

따라서 self.bn1(x, training=training)은 입력 데이터 x에 배치 정규화를 적용하고, 
훈련 중인지 여부에 따라 적절한 통계 값을 사용하여 정규화를 수행합니다.
"""
def ResNet50():
    return ResNet(num_block=[3,4,5,3])

def get_model():
    model=ResNet50()
    model.build(input_shape=(None,32,32,3))
    model.summary()
    return model

model=get_model()
"""
여기서 input_shape은 모델의 입력 데이터의 형태를 지정합니다. (None, 224, 224, 3)은 
각각 배치 크기를 제외한 이미지의 높이, 너비 및 채널 수를 나타냅니다.

모델은 처음 사용될 때 자동으로 build 메서드를 호출하며, 이때 입력 데이터의 형태에 
맞추어 가중치를 생성합니다. 따라서 모델을 처음 사용하기 전에 build 메서드를 
명시적으로 호출하여 가중치를 초기화할 수도 있습니다."""
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A5AE9E3C8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A5AE9E3C8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A5AE9E3C8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD59888>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD59888>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD59888>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD6AE88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD6AE88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD6AE88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD81848>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD81848>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD81848>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD8EF48>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD8EF48>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AD8EF48>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADA1D88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADA1D88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADA1D88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADB2908>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADB2908>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADB2908>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADC6788>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADC6788>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADC6788>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADD3E08>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADD3E08>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADD3E08>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADE7F88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADE7F88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADE7F88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADFA688>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADFA688>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4ADFA688>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE09F88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE09F88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE09F88>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE1FAC8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE1FAC8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE1FAC8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE2F188>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE2F188>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE2F188>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE3FEC8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING:tensorflow:AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE3FEC8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <bound method BottleNeck.call of <__main__.BottleNeck object at 0x0000010A4AE3FEC8>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# Model: "res_net_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_61 (Conv2D)           multiple                  9472
# _________________________________________________________________
# batch_normalization_62 (Batc multiple                  256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 multiple                  0
# _________________________________________________________________
# batch_normalization_63 (Batc multiple                  256
# _________________________________________________________________
# sequential_19 (Sequential)   multiple                  353664
# _________________________________________________________________
# sequential_23 (Sequential)   multiple                  2024448
# _________________________________________________________________
# sequential_28 (Sequential)   multiple                  10222080
# _________________________________________________________________
# sequential_34 (Sequential)   multiple                  23407616
# _________________________________________________________________
# average_pooling2d_1 (Average multiple                  0
# _________________________________________________________________
# flatten_1 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_3 (Dense)              multiple                  4196352
# _________________________________________________________________
# dense_4 (Dense)              multiple                  2049000
# _________________________________________________________________
# dense_5 (Dense)              multiple                  10010
# =================================================================
# Total params: 42,273,154
# Trainable params: 42,202,498
# Non-trainable params: 70,656
# _________________________________________________________________
# '\n여기서 input_shape은 모델의 입력 데이터의 형태를 지정합니다. (None, 224, 224, 3)은 \n각각 배치 크기를 제외한 이미지의 높이, 너비 및 채널 수를 나타냅니다.\n\n모델은 처음 사용될 때 자동으로 build 메서드를 호출하며, 이때 입력 데이터의 형태에 \n맞추어 가중치를 생성합니다. 따라서 모델을 처음 사용하기 전에 build 메서드를 \n명시적으로 호출하여 가중치를 초기화할 수도 있습니다.'

# %%
def visualize_data(images, categories, class_names):
    fig = plt.figure(figsize=(14, 6))
    fig.patch.set_facecolor('white')
    for i in range(3 * 7):
        plt.subplot(3, 7, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(images[i])
        class_index = categories[i].argmax()
        plt.xlabel(class_names[class_index])
    plt.show()
def load_cifar10_dataset():
    (train_validation_images, train_validation_labels), (test_images, test_labels) \
    = cifar10.load_data()
    
    train_validation_images = train_validation_images / 255
    test_images = test_images / 255.
    
    width_shift = 3/33
    height_shift = 3/32
    flip = True
    
    class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
    num_classes = len(class_names)

    datagen = ImageDataGenerator(
    horizontal_flip=flip,
    width_shift_range=width_shift,
    height_shift_range=height_shift,
    )
    datagen.fit(train_x)
    it = datagen.flow(train_x, train_x, shuffle=False)
    batch_images, batch_labels = next(it)
    visualize_data(batch_images, batch_labels, class_names)
    
    n_train_validation = train_validation_images.shape[0]
    train_ratio = 0.8
    n_train = int(n_train_validation * train_ratio)
    
    train_x = train_validation_images[:n_train]
    train_y = train_validation_labels[:n_train]
    validation_x = train_validation_images[n_train:]
    validation_y = train_validation_labels[n_train:]
    test_x = test_images
    test_y = test_labels

    print('Train set')
    print('Image :', batch_images.shape)
    print('Label :', batch_labels.shape)
    print('Validation set')
    print('Image :', validation_x.shape)
    print('Label :', validation_y.shape)
    print('Train & validation set')
    print('Image :', test_x.shape)
    print('Label :', test_y.shape)
    
    return batch_images, batch_labels, validation_x, validation_y, test_x, test_y
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 104

# %%
batch_images, batch_labels, validation_x, validation_y, test_x, test_y = load_cifar10_dataset()


batch_labels= to_categorical(batch_labels,10)

validation_y = to_categorical(validation_y,10)

test_y = to_categorical(test_y,10)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\1585185143.py", line 1, in <module>
#     batch_images, batch_labels, validation_x, validation_y, test_x, test_y = load_cifar10_dataset()
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\4145947123.py", line 45, in load_cifar10_dataset
#     visualize_data(batch_images, batch_labels, class_names)
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\4145947123.py", line 10, in visualize_data
#     plt.xlabel(class_names[class_index])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\1585185143.py", line 1, in <module>
#     batch_images, batch_labels, validation_x, validation_y, test_x, test_y = load_cifar10_dataset()
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\4145947123.py", line 45, in load_cifar10_dataset
#     visualize_data(batch_images, batch_labels, class_names)
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\4145947123.py", line 10, in visualize_data
#     plt.xlabel(class_names[class_index])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\1585185143.py", line 1, in <module>
#     batch_images, batch_labels, validation_x, validation_y, test_x, test_y = load_cifar10_dataset()
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\4145947123.py", line 45, in load_cifar10_dataset
#     visualize_data(batch_images, batch_labels, class_names)
#   File "C:\Users\tlsdu\AppData\Local\Temp\ipykernel_19116\4145947123.py", line 10, in visualize_data
#     plt.xlabel(class_names[class_index])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
# EarlyStopping 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss',  # 모니터링할 성능 지표
                               patience=5,          # 성능 향상이 없을 때 몇 번까지 기다릴지 설정
                               restore_best_weights=True) 
model.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit(train_x, train_y, epochs=100, batch_size=64,validation_data=(validation_x, validation_y))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 85
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/100
# 40000/40000 [==============================] - 49s 1ms/sample - loss: 0.0541 - accuracy: 0.9844 - val_loss: 1.7252 - val_accuracy: 0.7024
# Epoch 2/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0455 - accuracy: 0.9858 - val_loss: 1.4068 - val_accuracy: 0.7519
# Epoch 3/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0487 - accuracy: 0.9852 - val_loss: 1.3099 - val_accuracy: 0.7573
# Epoch 4/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.1473 - accuracy: 0.9525 - val_loss: 1.2332 - val_accuracy: 0.7344
# Epoch 5/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0508 - accuracy: 0.9848 - val_loss: 1.3018 - val_accuracy: 0.7584
# Epoch 6/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0266 - accuracy: 0.9919 - val_loss: 1.5409 - val_accuracy: 0.7472
# Epoch 7/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0338 - accuracy: 0.9900 - val_loss: 1.5365 - val_accuracy: 0.7287
# Epoch 8/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0653 - accuracy: 0.9801 - val_loss: 1.1782 - val_accuracy: 0.7447
# Epoch 9/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0540 - accuracy: 0.9836 - val_loss: 1.5537 - val_accuracy: 0.7283
# Epoch 10/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0344 - accuracy: 0.9896 - val_loss: 1.4929 - val_accuracy: 0.7429
# Epoch 11/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0353 - accuracy: 0.9890 - val_loss: 1.3617 - val_accuracy: 0.7532
# Epoch 12/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0345 - accuracy: 0.9902 - val_loss: 1.3764 - val_accuracy: 0.7335
# Epoch 13/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0384 - accuracy: 0.9887 - val_loss: 1.3748 - val_accuracy: 0.7583
# Epoch 14/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0841 - accuracy: 0.9748 - val_loss: 1.1350 - val_accuracy: 0.7588
# Epoch 15/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0458 - accuracy: 0.9856 - val_loss: 1.2815 - val_accuracy: 0.7573
# Epoch 16/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0418 - accuracy: 0.9882 - val_loss: 1.3440 - val_accuracy: 0.7441
# Epoch 17/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0329 - accuracy: 0.9901 - val_loss: 1.3536 - val_accuracy: 0.7581
# Epoch 18/100
# 40000/40000 [==============================] - 46s 1ms/sample - loss: 0.0522 - accuracy: 0.9833 - val_loss: 1.2635 - val_accuracy: 0.7598
# Epoch 19/100
# 40000/40000 [==============================] - 45s 1ms/sample - loss: 0.0429 - accuracy: 0.9872 - val_loss: 1.4026 - val_accuracy: 0.7520
# Epoch 20/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0290 - accuracy: 0.9911 - val_loss: 1.3490 - val_accuracy: 0.7648
# Epoch 21/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0321 - accuracy: 0.9907 - val_loss: 1.4056 - val_accuracy: 0.7396
# Epoch 22/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0382 - accuracy: 0.9888 - val_loss: 1.4442 - val_accuracy: 0.7501
# Epoch 23/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0356 - accuracy: 0.9895 - val_loss: 1.3778 - val_accuracy: 0.7428
# Epoch 24/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0313 - accuracy: 0.9906 - val_loss: 1.6748 - val_accuracy: 0.7276
# Epoch 25/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0346 - accuracy: 0.9894 - val_loss: 1.4433 - val_accuracy: 0.7447
# Epoch 26/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0305 - accuracy: 0.9912 - val_loss: 1.7223 - val_accuracy: 0.7102
# Epoch 27/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0321 - accuracy: 0.9901 - val_loss: 1.4653 - val_accuracy: 0.7535
# Epoch 28/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0353 - accuracy: 0.9904 - val_loss: 1.3807 - val_accuracy: 0.7544
# Epoch 29/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0317 - accuracy: 0.9911 - val_loss: 1.6054 - val_accuracy: 0.7313
# Epoch 30/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.1336 - accuracy: 0.9601 - val_loss: 1.1855 - val_accuracy: 0.7503
# Epoch 31/100
# 40000/40000 [==============================] - 45s 1ms/sample - loss: 0.0461 - accuracy: 0.9868 - val_loss: 1.2874 - val_accuracy: 0.7644
# Epoch 32/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0156 - accuracy: 0.9956 - val_loss: 1.5088 - val_accuracy: 0.7644
# Epoch 33/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0253 - accuracy: 0.9930 - val_loss: 1.6958 - val_accuracy: 0.7240
# Epoch 34/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0290 - accuracy: 0.9921 - val_loss: 1.4769 - val_accuracy: 0.7589
# Epoch 35/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0226 - accuracy: 0.9931 - val_loss: 1.6550 - val_accuracy: 0.7505
# Epoch 36/100
# 40000/40000 [==============================] - 45s 1ms/sample - loss: 0.0227 - accuracy: 0.9935 - val_loss: 1.5815 - val_accuracy: 0.7428
# Epoch 37/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0314 - accuracy: 0.9905 - val_loss: 1.4188 - val_accuracy: 0.7616
# Epoch 38/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0432 - accuracy: 0.9879 - val_loss: 1.3416 - val_accuracy: 0.7469
# Epoch 39/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0736 - accuracy: 0.9778 - val_loss: 1.2753 - val_accuracy: 0.7615
# Epoch 40/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0784 - accuracy: 0.9790 - val_loss: 1.2683 - val_accuracy: 0.7617
# Epoch 41/100
# 40000/40000 [==============================] - 46s 1ms/sample - loss: 0.0233 - accuracy: 0.9936 - val_loss: 1.3969 - val_accuracy: 0.7543
# Epoch 42/100
# 40000/40000 [==============================] - 49s 1ms/sample - loss: 0.0254 - accuracy: 0.9931 - val_loss: 1.3600 - val_accuracy: 0.7642
# Epoch 43/100
# 40000/40000 [==============================] - 51s 1ms/sample - loss: 0.0360 - accuracy: 0.9892 - val_loss: 1.5475 - val_accuracy: 0.7409
# Epoch 44/100
# 40000/40000 [==============================] - 54s 1ms/sample - loss: 0.0243 - accuracy: 0.9930 - val_loss: 1.3909 - val_accuracy: 0.7577
# Epoch 45/100
# 40000/40000 [==============================] - 54s 1ms/sample - loss: 0.0227 - accuracy: 0.9934 - val_loss: 1.3200 - val_accuracy: 0.7643
# Epoch 46/100
# 40000/40000 [==============================] - 46s 1ms/sample - loss: 0.0340 - accuracy: 0.9901 - val_loss: 1.6688 - val_accuracy: 0.7248
# Epoch 47/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0268 - accuracy: 0.9922 - val_loss: 1.4599 - val_accuracy: 0.7586
# Epoch 48/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0279 - accuracy: 0.9917 - val_loss: 1.7035 - val_accuracy: 0.7227
# Epoch 49/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0289 - accuracy: 0.9909 - val_loss: 1.4393 - val_accuracy: 0.7546
# Epoch 50/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0266 - accuracy: 0.9921 - val_loss: 1.4554 - val_accuracy: 0.7628
# Epoch 51/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0276 - accuracy: 0.9923 - val_loss: 1.4064 - val_accuracy: 0.7630
# Epoch 52/100
# 40000/40000 [==============================] - 46s 1ms/sample - loss: 0.0279 - accuracy: 0.9923 - val_loss: 1.6093 - val_accuracy: 0.7404
# Epoch 53/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0292 - accuracy: 0.9911 - val_loss: 1.5008 - val_accuracy: 0.7479
# Epoch 54/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0275 - accuracy: 0.9918 - val_loss: 1.6038 - val_accuracy: 0.7311
# Epoch 55/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0273 - accuracy: 0.9918 - val_loss: 1.5133 - val_accuracy: 0.7508
# Epoch 56/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0238 - accuracy: 0.9928 - val_loss: 1.5727 - val_accuracy: 0.7500
# Epoch 57/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0597 - accuracy: 0.9822 - val_loss: 1.2360 - val_accuracy: 0.7473
# Epoch 58/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0277 - accuracy: 0.9923 - val_loss: 1.3651 - val_accuracy: 0.7646
# Epoch 59/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0174 - accuracy: 0.9954 - val_loss: 1.5207 - val_accuracy: 0.7619
# Epoch 60/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0218 - accuracy: 0.9931 - val_loss: 1.4116 - val_accuracy: 0.7559
# Epoch 61/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0243 - accuracy: 0.9928 - val_loss: 1.6251 - val_accuracy: 0.7376
# Epoch 62/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0263 - accuracy: 0.9923 - val_loss: 1.3731 - val_accuracy: 0.7624
# Epoch 63/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0278 - accuracy: 0.9915 - val_loss: 1.3676 - val_accuracy: 0.7677
# Epoch 64/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0243 - accuracy: 0.9930 - val_loss: 1.4011 - val_accuracy: 0.7498
# Epoch 65/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0418 - accuracy: 0.9879 - val_loss: 1.3804 - val_accuracy: 0.7450
# Epoch 66/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0187 - accuracy: 0.9945 - val_loss: 1.5460 - val_accuracy: 0.7612
# Epoch 67/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0225 - accuracy: 0.9935 - val_loss: 1.4092 - val_accuracy: 0.7607
# Epoch 68/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0484 - accuracy: 0.9863 - val_loss: 1.4458 - val_accuracy: 0.7306
# Epoch 69/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0311 - accuracy: 0.9915 - val_loss: 1.5896 - val_accuracy: 0.7553
# Epoch 70/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0167 - accuracy: 0.9951 - val_loss: 1.4198 - val_accuracy: 0.7683
# Epoch 71/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0188 - accuracy: 0.9941 - val_loss: 1.4972 - val_accuracy: 0.7563
# Epoch 72/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0199 - accuracy: 0.9939 - val_loss: 1.4885 - val_accuracy: 0.7626
# Epoch 73/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0185 - accuracy: 0.9944 - val_loss: 1.9278 - val_accuracy: 0.7234
# Epoch 74/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0251 - accuracy: 0.9924 - val_loss: 1.5739 - val_accuracy: 0.7368
# Epoch 75/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0219 - accuracy: 0.9936 - val_loss: 1.4311 - val_accuracy: 0.7588
# Epoch 76/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0171 - accuracy: 0.9945 - val_loss: 1.6252 - val_accuracy: 0.7430
# Epoch 77/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0433 - accuracy: 0.9883 - val_loss: 1.3491 - val_accuracy: 0.7571
# Epoch 78/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0708 - accuracy: 0.9794 - val_loss: 1.2725 - val_accuracy: 0.7527
# Epoch 79/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0234 - accuracy: 0.9935 - val_loss: 1.4573 - val_accuracy: 0.7605
# Epoch 80/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0113 - accuracy: 0.9967 - val_loss: 1.5246 - val_accuracy: 0.7627
# Epoch 81/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0147 - accuracy: 0.9956 - val_loss: 2.1292 - val_accuracy: 0.7011
# Epoch 82/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0206 - accuracy: 0.9939 - val_loss: 1.4599 - val_accuracy: 0.7593
# Epoch 83/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0180 - accuracy: 0.9945 - val_loss: 1.5819 - val_accuracy: 0.7598
# Epoch 84/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0349 - accuracy: 0.9897 - val_loss: 1.6465 - val_accuracy: 0.7678
# Epoch 85/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0547 - accuracy: 0.9846 - val_loss: 1.2217 - val_accuracy: 0.7548
# Epoch 86/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0373 - accuracy: 0.9889 - val_loss: 1.8548 - val_accuracy: 0.7303
# Epoch 87/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0203 - accuracy: 0.9944 - val_loss: 1.6601 - val_accuracy: 0.7455
# Epoch 88/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0183 - accuracy: 0.9947 - val_loss: 1.4752 - val_accuracy: 0.7624
# Epoch 89/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0525 - accuracy: 0.9852 - val_loss: 1.5621 - val_accuracy: 0.7610
# Epoch 90/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0159 - accuracy: 0.9953 - val_loss: 1.4252 - val_accuracy: 0.7663
# Epoch 91/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0120 - accuracy: 0.9963 - val_loss: 1.6029 - val_accuracy: 0.7591
# Epoch 92/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0198 - accuracy: 0.9940 - val_loss: 1.4741 - val_accuracy: 0.7529
# Epoch 93/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0151 - accuracy: 0.9957 - val_loss: 1.4764 - val_accuracy: 0.7615
# Epoch 94/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0163 - accuracy: 0.9951 - val_loss: 1.4775 - val_accuracy: 0.7606
# Epoch 95/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0254 - accuracy: 0.9923 - val_loss: 1.5373 - val_accuracy: 0.7599
# Epoch 96/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0222 - accuracy: 0.9937 - val_loss: 1.4316 - val_accuracy: 0.7598
# Epoch 97/100
# 40000/40000 [==============================] - 43s 1ms/sample - loss: 0.0208 - accuracy: 0.9939 - val_loss: 1.4135 - val_accuracy: 0.7623
# Epoch 98/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0270 - accuracy: 0.9925 - val_loss: 1.3452 - val_accuracy: 0.7628
# Epoch 99/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0260 - accuracy: 0.9923 - val_loss: 1.8582 - val_accuracy: 0.7403
# Epoch 100/100
# 40000/40000 [==============================] - 44s 1ms/sample - loss: 0.0227 - accuracy: 0.9952 - val_loss: 1.5123 - val_accuracy: 0.7313

# %%
test_loss, test_acc = model.evaluate(test_x, test_y)
# Out:
# 10000/10000 [==============================] - 4s 423us/sample - loss: 1.5525 - accuracy: 0.7288

# %%
fig, axes = plt.subplots(2,1)

axes[0].plot(history.history['loss'], label='Train loss')
axes[0].plot(history.history['val_loss'], label='Validation loss')
axes[0].set_ylabel('Crossentropy')
axes[0].legend()

axes[1].plot(history.history['accuracy'], label='Train accuracy')
axes[1].plot(history.history['val_accuracy'], label='Validation accuracy')
axes[1].set_ylabel('Accuarcy')
axes[1].legend()
axes[1].set_xlabel('Epochs')

fig.show()
# Out:
# C:\Users\tlsdu\anaconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
import cv2
img = cv2.imread('cat_image.jpg') #사진 읽어들이기

#이미지 출력

plt.imshow(img)
plt.show()

# %%
img=cv2.resize(img,(32,32))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()

"""
resize는 이미지 크기가 변하는 것이 아닌 픽셀 수가 변경되는 것이다. 픽셀수를 줄이면
그만큼 파일을 손상한 것이기 때문에 다시 늘린다고 원본의 해상도로 돌릴 수 없다.
"""
# Out:
# '\nresize는 이미지 크기가 변하는 것이 아닌 픽셀 수가 변경되는 것이다. 픽셀수를 줄이면\n그만큼 파일을 손상한 것이기 때문에 다시 늘린다고 원본의 해상도로 돌릴 수 없다.\n'

# %%
img = np.expand_dims(img, axis=0)  # 4차원으로 확장
print(img.shape)
# Out:
# (1, 32, 32, 3)

# %%
predictions = model.predict(img)

# Define the class labels for CIFAR-10
class_labels = ["Airplane", "Automobile", "Bird", "Cat", "Deer", "Dog", "Frog", "Horse", "Ship", "Truck"]

# Interpret the results
predicted_class = np.argmax(predictions)
predicted_label = class_labels[predicted_class]

# Display the image and predicted class label
plt.title(f"Predicted Class: {predicted_label}")
plt.imshow(img[0])
plt.show()
